# %%
import numpy as np
import os

from keras.models import Sequential
from keras.layers import Dense, Conv2D
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import Adam

from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping


from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
x_train= '/content/drive/MyDrive/AI/tropical_fruits/x_train'
x_test= '/content/drive/MyDrive/AI/tropical_fruits/x_test'

# %%
x_train = ImageDataGenerator(rescale=1/255)
x_test = ImageDataGenerator(rescale=1/255)

# %%
x_train_data = x_train.flow_from_directory(
    directory=r"/content/drive/MyDrive/AI/tropical_fruits/x_train",
    target_size=(224, 224),
    batch_size=3,
    class_mode='categorical',
    )
x_test_data = x_test.flow_from_directory(
    directory=r"/content/drive/MyDrive/AI/tropical_fruits/x_test",
    target_size=(224, 224),
    batch_size=3,
    class_mode= "categorical",
    )
# Out:
# Found 66 images belonging to 10 classes.
# Found 28 images belonging to 10 classes.

# %%
x_train_data.class_indices
# Out:
# {'apple': 0,
#  'banana': 1,
#  'cherry': 2,
#  'coconut': 3,
#  'durian': 4,
#  'kiwi': 5,
#  'mango': 6,
#  'orange': 7,
#  'pomelo': 8,
#  'water melon': 9}

# %%
  model = Sequential()

  model.add(Conv2D(32,(3,3),input_shape=(224,224,3),padding='same',activation='relu'))
  model.add(Dropout(0.2))

  model.add(Conv2D(32,(3,3),activation='relu',padding='same'))
  model.add(MaxPooling2D(pool_size=(4,4)))

  model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
  model.add(Dropout(0.2))

  model.add(Conv2D(64,(3,3),activation='relu',padding='same'))
  model.add(MaxPooling2D(pool_size=(2,2)))

  model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
  model.add(Dropout(0.2))

  model.add(Conv2D(128,(3,3),activation='relu',padding='same'))
  model.add(MaxPooling2D(pool_size=(2,2)))

  model.add(Flatten())
  model.add(Dropout(0.2))

  model.add(Dense(1026,activation='relu'))
  model.add(Dropout(0.2))

  model.add(Dense(512,activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(100,activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(10,activation='softmax'))
  model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  dropout (Dropout)           (None, 224, 224, 32)      0
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 56, 56, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 64)        18496
#
#  dropout_1 (Dropout)         (None, 56, 56, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 56, 56, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 128)       73856
#
#  dropout_2 (Dropout)         (None, 28, 28, 128)       0
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout_3 (Dropout)         (None, 25088)             0
#
#  dense (Dense)               (None, 1026)              25741314
#
#  dropout_4 (Dropout)         (None, 1026)              0
#
#  dense_1 (Dense)             (None, 512)               525824
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 100)               51300
#
#  dropout_6 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 26,606,456
# Trainable params: 26,606,456
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=0.0005), loss='categorical_crossentropy', metrics=['accuracy'])
history=model.fit(x_train_data,
                  epochs=70,
                  batch_size=64,
                  verbose=1,
                  validation_data= x_test_data)
# Out:
# Epoch 1/70
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 22/22 [==============================] - 3s 86ms/step - loss: 0.1013 - accuracy: 0.9697 - val_loss: 22.1640 - val_accuracy: 0.1786
# Epoch 2/70
# 22/22 [==============================] - 2s 75ms/step - loss: 0.0394 - accuracy: 0.9848 - val_loss: 20.0502 - val_accuracy: 0.1786
# Epoch 3/70
# 22/22 [==============================] - 2s 77ms/step - loss: 9.8242e-04 - accuracy: 1.0000 - val_loss: 18.9114 - val_accuracy: 0.0714
# Epoch 4/70
# 22/22 [==============================] - 2s 75ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 20.6133 - val_accuracy: 0.0714
# Epoch 5/70
# 22/22 [==============================] - 2s 76ms/step - loss: 5.2627e-06 - accuracy: 1.0000 - val_loss: 21.2683 - val_accuracy: 0.0714
# Epoch 6/70
# 22/22 [==============================] - 2s 71ms/step - loss: 3.8940e-06 - accuracy: 1.0000 - val_loss: 21.3889 - val_accuracy: 0.0714
# Epoch 7/70
# 22/22 [==============================] - 2s 71ms/step - loss: 1.2344e-04 - accuracy: 1.0000 - val_loss: 21.2538 - val_accuracy: 0.1071
# Epoch 8/70
# 22/22 [==============================] - 2s 77ms/step - loss: 1.3007e-05 - accuracy: 1.0000 - val_loss: 21.0238 - val_accuracy: 0.1071
# Epoch 9/70
# 22/22 [==============================] - 2s 75ms/step - loss: 3.4665e-04 - accuracy: 1.0000 - val_loss: 22.2199 - val_accuracy: 0.1429
# Epoch 10/70
# 22/22 [==============================] - 2s 74ms/step - loss: 9.6451e-05 - accuracy: 1.0000 - val_loss: 22.3754 - val_accuracy: 0.1429
# Epoch 11/70
# 22/22 [==============================] - 2s 86ms/step - loss: 0.0213 - accuracy: 0.9848 - val_loss: 36.3990 - val_accuracy: 0.1429
# Epoch 12/70
# 22/22 [==============================] - 2s 70ms/step - loss: 1.6392 - accuracy: 0.8939 - val_loss: 19.7598 - val_accuracy: 0.1786
# Epoch 13/70
# 22/22 [==============================] - 2s 75ms/step - loss: 0.3074 - accuracy: 0.9242 - val_loss: 10.7057 - val_accuracy: 0.1071
# Epoch 14/70
# 22/22 [==============================] - 2s 77ms/step - loss: 0.2883 - accuracy: 0.9697 - val_loss: 10.4584 - val_accuracy: 0.1071
# Epoch 15/70
# 22/22 [==============================] - 2s 76ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 10.4376 - val_accuracy: 0.1071
# Epoch 16/70
# 22/22 [==============================] - 2s 90ms/step - loss: 0.2847 - accuracy: 0.9394 - val_loss: 11.2466 - val_accuracy: 0.1786
# Epoch 17/70
# 22/22 [==============================] - 2s 72ms/step - loss: 0.0272 - accuracy: 1.0000 - val_loss: 12.2378 - val_accuracy: 0.1071
# Epoch 18/70
# 22/22 [==============================] - 2s 73ms/step - loss: 0.0147 - accuracy: 0.9848 - val_loss: 12.1518 - val_accuracy: 0.1071
# Epoch 19/70
# 22/22 [==============================] - 2s 73ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss:
# 22/22 [==============================] - 2s 74ms/step - loss: 4.4702e-06 - accuracy: 1.0000 - val_loss: 12.6871 - val_accuracy: 0.1429
# Epoch 59/70
# 22/22 [==============================] - 2s 78ms/step - loss: 1.3380e-05 - accuracy: 1.0000 - val_loss: 12.7339 - val_accuracy: 0.1429
# Epoch 60/70
# 22/22 [==============================] - 2s 81ms/step - loss: 2.8013e-04 - accuracy: 1.0000 - val_loss: 13.3278 - val_accuracy: 0.1429
# Epoch 61/70
# 22/22 [==============================] - 2s 76ms/step - loss: 4.7067e-06 - accuracy: 1.0000 - val_loss: 13.8107 - val_accuracy: 0.1071
# Epoch 62/70
# 22/22 [==============================] - 2s 78ms/step - loss: 3.4475e-05 - accuracy: 1.0000 - val_loss: 13.7482 - val_accuracy: 0.1429
# Epoch 63/70
# 22/22 [==============================] - 2s 74ms/step - loss: 4.5928e-06 - accuracy: 1.0000 - val_loss: 13.7730 - val_accuracy: 0.1429
# Epoch 64/70
# 22/22 [==============================] - 2s 64ms/step - loss: 1.5569e-06 - accuracy: 1.0000 - val_loss: 13.8130 - val_accuracy: 0.1429
# Epoch 65/70
# 22/22 [==============================] - 2s 76ms/step - loss: 1.9001e-06 - accuracy: 1.0000 - val_loss: 13.8263 - val_accuracy: 0.1429
# Epoch 66/70
# 22/22 [==============================] - 2s 78ms/step - loss: 1.3004e-06 - accuracy: 1.0000 - val_loss: 13.8389 - val_accuracy: 0.1429
# Epoch 67/70
# 22/22 [==============================] - 2s 74ms/step - loss: 1.8639e-06 - accuracy: 1.0000 - val_loss: 13.8258 - val_accuracy: 0.1429
# Epoch 68/70
# 22/22 [==============================] - 2s 81ms/step - loss: 5.8213e-05 - accuracy: 1.0000 - val_loss: 13.9749 - val_accuracy: 0.1429
# Epoch 69/70
# 22/22 [==============================] - 2s 80ms/step - loss: 2.2324e-06 - accuracy: 1.0000 - val_loss: 14.0147 - val_accuracy: 0.1429
# Epoch 70/70
# 22/22 [==============================] - 2s 74ms/step - loss: 1.4810e-06 - accuracy: 1.0000 - val_loss: 14.0298 - val_accuracy: 0.1429

# %%
model.save('nhandientraicay.h5')

# %%
from keras.models import load_model
nhandangtraicay = load_model('nhandientraicay.h5')

# %%
from keras.preprocessing.image import load_img, img_to_array
img = load_img('/content/drive/MyDrive/AI/tropical_fruits/x_test/mango/1.jpg', target_size =(224,224))
plt.imshow(img)
img = img_to_array(img)
img = img.reshape(1,224,224,3)
img = img.astype('float32')
img = img/255
img.shape
# Out:
# (1, 224, 224, 3)

# %%
np.argmax(nhandangtraicay.predict(img),axis= 1)
# Out:
# array([5])

# %% [markdown]
# {'apple': 0,
#  'banana': 1,
#  'cherry': 2,
#  'coconut': 3,
#  'durian': 4,
#  'kiwi': 5,
#  'mango': 6,
#  'orange': 7,
#  'pomelo': 8,
#  'water melon': 9}
